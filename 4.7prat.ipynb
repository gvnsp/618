# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
from skimpy import clean_columns

# %%
os.chdir("C:/Users/gvnsp/SI618/618-main")

# %% [markdown]
# # Load Data

# %%
DATA_DIR = 'data'
def data_path(filename, data_dir = DATA_DIR):
    return f"{data_dir}/{filename}"
air_pollution_filename = "air_pollution_emissions.csv"
alcohol_expenditure_filename = "alcohol_expenditure_usa_long_term.csv"
cancer_death_filename = "cancer_death_rates_in_the_US_over_the_long_term.csv"
hospital_admissions_filename = "total-hospital-admissions-in-the-united-states-1946-2019.xlsx"
demographic_indicators_filename = "WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_COMPACT_REV1.xlsx"

# %% [markdown]
# ### Hospital Admissions

# %%
# read data
hospital_admissions = pd.read_excel(data_path(hospital_admissions_filename), sheet_name = 1)
# remove junk columns & rows
hospital_admissions = hospital_admissions.drop(columns=['Unnamed: 0'])
hospital_admissions = hospital_admissions.iloc[4:,:]
# rename columns
hospital_admissions.rename(columns={'Unnamed: 1':'year', 'Unnamed: 2':'num_admissions_1000s'}, inplace=True)
# fix type
hospital_admissions['year'] = pd.to_numeric(hospital_admissions['year'])
# set dates
hospital_admissions = hospital_admissions.loc[(hospital_admissions['year'] >= 1950) & (hospital_admissions['year'] <= 2011)]
hospital_admissions.set_index('year', inplace=True)

# %%
hospital_admissions.head(10)
# Out:
#       num_admissions_1000s
# year
# 1950               18483.0
# 1955               21073.0
# 1960               25027.0
# 1965               28812.0
# 1970               31759.0
# 1971               32664.0
# 1972               33265.0
# 1973               34352.0
# 1974               35506.0
# 1975               36157.0

# %%
hospital_admissions['num_admissions_1000s'].plot(style='.')
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# ### Demographic Indicators

# %%
# read data
demographic_indicators = pd.read_excel(data_path(demographic_indicators_filename), sheet_name=0)
# remove junk rows and set header
demographic_indicators_header = demographic_indicators.iloc[15,:]
demographic_indicators = demographic_indicators.iloc[16:,:]
demographic_indicators.columns = demographic_indicators_header
# select USA data
demographic_indicators = demographic_indicators.loc[demographic_indicators['Region, subregion, country or area *'] == 'United States of America']
# rename columns
demographic_indicators.rename(
    columns={'Year': 'year',
             'Total Population, as of 1 July (thousands)': 'total_population',
             'Male Population, as of 1 July (thousands)': 'male_population',
             'Female Population, as of 1 July (thousands)': 'female_population'},
    inplace=True)
# select relevant columns
demographic_cols = ['year', 'total_population', 'male_population', 'female_population']
demographic_indicators = demographic_indicators[demographic_cols]
# set dates and index
demographic_indicators = demographic_indicators.loc[(demographic_indicators['year'] >= 1950) & (demographic_indicators['year'] <= 2011)]
demographic_indicators.columns.name = None
demographic_indicators.set_index('year', inplace=True)
demographic_indicators
# Out:
#      total_population male_population female_population
# year
# 1950        148281.55       73516.095         74765.455
# 1951       150598.453       74784.499         75813.955
# 1952       152941.727       76079.283         76862.444
# 1953       155451.199       77221.443         78229.756
# 1954       158205.873       78577.893          79627.98
# ...               ...             ...               ...
# 2007       302743.399       149147.06        153596.338
# 2008        305694.91      150592.791         155102.12
# 2009       308512.035      151968.684        156543.351
# 2010       311182.845      153272.866        157909.979
# 2011       313876.608      154669.482        159207.127
#
# [62 rows x 3 columns]

# %% [markdown]
# ### Cancer Death Rates (per 100,000)

# %%
# read data
cancer_death = pd.read_csv(data_path(cancer_death_filename))
# set dates
cancer_death = cancer_death.loc[(cancer_death['Year'] >= 1950) & (cancer_death['Year'] <= 2011)]
# basic cleaning
cancer_death = clean_columns(cancer_death)
cancer_death.drop('entity', axis=1, inplace=True)
cancer_death.set_index('year', inplace=True)
cancer_death.head()
# Out:
# 16 column names have been cleaned
#       stomach_male  colon_and_rectum_male  liver_male  pancreas_male  \
# year
# 1950          31.1                   33.1         8.6            9.9
# 1951          29.7                   32.3         8.3           10.3
# 1952          28.7                   32.8         8.1           10.4
# 1953          28.1                   33.0         8.0           10.7
# 1954          27.3                   32.6         7.7           11.2
#
#       lung_and_bronchus_male  prostate_male  leukemia_male  stomach_female  \
# year
# 1950                    24.3           28.9            8.2            17.6
# 1951                    25.8           28.6            8.7            16.5
# 1952                    28.0           29.7            8.8            16.1
# 1953                    30.4           29.8            9.1            15.6
# 1954                    31.7           30.5            9.4            14.8
#
#       colon_and_rectum_female  pancreas_female  lung_and_bronchus_female  \
# year
# 1950                     32.3              6.8                       5.8
# 1951                     31.9              6.7                       5.9
# 1952                     31.5              7.1                       6.1
# 1953                     31.4              7.1                       6.0
# 1954                     31.2              7.3                       6.0
#
#       breast_female  uterus_female  liver_female
# year
# 1950           31.9           26.2           9.8
# 1951           31.6           24.5           9.4
# 1952           31.6           23.8           9.5
# 1953           32.2           23.6           9.2
# 1954           31.8           22.5           8.7

# %% [markdown]
# ### Alcohol Expenditure

# %%
alcohol_expenditure = pd.read_csv(data_path(alcohol_expenditure_filename))
# select dates
alcohol_expenditure = alcohol_expenditure.loc[(alcohol_expenditure['Year'] >= 1950) & (alcohol_expenditure['Year'] <= 2011)]
# clean names and set index
alcohol_expenditure = clean_columns(alcohol_expenditure)
alcohol_expenditure.set_index('year', inplace=True)
# rename and subset relevant cols
alcohol_expenditure.rename(
    columns={'total_at_home_usda_2018': 'alc_exp_at_home',
             'total_away_from_home': 'alc_exp_away_fr_home',
             'total_alcohol_expenditure_usda_2018': 'alc_exp_total'},
    inplace=True
)
relevant_alc_cols = [
    'alc_exp_at_home',
    'alc_exp_away_fr_home',
    'alc_exp_total'
]
alcohol_expenditure = alcohol_expenditure[relevant_alc_cols]
alcohol_expenditure.head()
# Out:
# 11 column names have been cleaned
#       alc_exp_at_home  alc_exp_away_fr_home  alc_exp_total
# year
# 1950       3455000000            4413000000     7868000000
# 1951       3789000000            4765000000     8554000000
# 1952       3999000000            4899000000     8898000000
# 1953       4080000000            4960000000     9040000000
# 1954       4189000000            4946000000     9135000000

# %% [markdown]
# ### Air Pollution

# %%
# read data
air_pollution = pd.read_csv(data_path(air_pollution_filename), low_memory=False)
# select USA data
air_pollution = air_pollution.loc[air_pollution['Entity'] == 'United States']
# fix column dtype
air_pollution['nh3_per_capita'] = pd.to_numeric(air_pollution['nh3_per_capita'])
# select dates 
air_pollution = air_pollution.loc[(air_pollution['Year'] >= 1950) & (air_pollution['Year'] <= 2011)]
# clean names and set index
air_pollution = clean_columns(air_pollution)
air_pollution.set_index('year', inplace=True)
# subset cols
air_pol_rel_cols = [
    'nox_per_capita', 
    'so_2_per_capita', 
    'co_per_capita', 
    'oc_per_capita',
    'nmvoc_per_capita', 
    'bc_per_capita', 
    'nh_3_per_capita'
]
air_pollution = air_pollution[air_pol_rel_cols]
air_pollution.head()
# Out:
# 6 column names have been cleaned
#       nox_per_capita  so_2_per_capita  co_per_capita  oc_per_capita  \
# year
# 1950       87.872567       113.791573     660.499190       6.120093
# 1951       92.284438       117.679654     681.203964       5.698752
# 1952       92.125837       111.202933     680.903893       5.305718
# 1953       93.192457       111.909954     690.662295       4.836261
# 1954       90.616479       102.869296     674.088049       4.476236
#
#       nmvoc_per_capita  bc_per_capita  nh_3_per_capita
# year
# 1950        106.463437       3.749932         9.289717
# 1951        111.268008       3.501867         9.570112
# 1952        112.090448       3.221975         9.744620
# 1953        114.208577       2.935008         9.946302
# 1954        112.303428       2.655331        10.007221

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# #### Hospital admissions
#
# Between 1950 and 1970, the data is recorded every 5 years. We will have to introduce the missing years into the data and fill in the missing values (using pandas' interpolation).

# %%
hospital_admissions = hospital_admissions.reindex(range(1950, 2012))
hospital_admissions.head(7)
# Out:
#       num_admissions_1000s
# year
# 1950               18483.0
# 1951                   NaN
# 1952                   NaN
# 1953                   NaN
# 1954                   NaN
# 1955               21073.0
# 1956                   NaN

# %% [markdown]
# We try 3 methods of interpolation – linear, quadratic and cubic, and plot their values.

# %%
hospital_admissions.interpolate(method='linear')['num_admissions_1000s'].plot(style='.')
# Out:
# <AxesSubplot: xlabel='year'>

# %%
hospital_admissions.interpolate(method='quadratic')['num_admissions_1000s'].plot(style='.')
# Out:
# <AxesSubplot: xlabel='year'>

# %%
hospital_admissions.interpolate(method='cubic')['num_admissions_1000s'].plot(style='.')
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# We see that the quadratic interpolation appears to give more realistic looking values when simply comparin their plots. When using cubic interpolation, we see that there does not appear to be any significant difference compared to the quadratic interpolation, and thus we settle on the quadratic interpolation, so as to avoid potential overfitting with a higher order polynomial interoplation.

# %%
hospital_admissions.interpolate(method='quadratic', inplace=True)

# %% [markdown]
# We are interested in the admissions per capita, and as such, in our pre-processing step we will multiply the `num_admissions_1000s` column by $1000$ in order to achieve the approximate raw number of approximations, which we will later divide by the population.

# %%
hospital_admissions['num_admissions_total'] = hospital_admissions['num_admissions_1000s'] * 1000
hospital_admissions.head()
# Out:
#       num_admissions_1000s  num_admissions_total
# year
# 1950          18483.000000          1.848300e+07
# 1951          18874.298477          1.887430e+07
# 1952          19328.947715          1.932895e+07
# 1953          19846.947715          1.984695e+07
# 1954          20428.298477          2.042830e+07

# %% [markdown]
# #### Joining and Further Processing

# %%
merged_df = hospital_admissions.copy()
dfs_to_merge = [
    demographic_indicators,
    cancer_death,
    alcohol_expenditure,
    air_pollution
]

# %%
for df in dfs_to_merge:
    merged_df = merged_df.merge(
        df, 
        how='left',
        left_index=True,
        right_index=True,
        suffixes=(None, None)
    )
merged_df.head()
# Out:
#       num_admissions_1000s  num_admissions_total total_population  \
# year
# 1950          18483.000000          1.848300e+07        148281.55
# 1951          18874.298477          1.887430e+07       150598.453
# 1952          19328.947715          1.932895e+07       152941.727
# 1953          19846.947715          1.984695e+07       155451.199
# 1954          20428.298477          2.042830e+07       158205.873
#
#      male_population female_population  stomach_male  colon_and_rectum_male  \
# year
# 1950       73516.095         74765.455          31.1                   33.1
# 1951       74784.499         75813.955          29.7                   32.3
# 1952       76079.283         76862.444          28.7                   32.8
# 1953       77221.443         78229.756          28.1                   33.0
# 1954       78577.893          79627.98          27.3                   32.6
#
#       liver_male  pancreas_male  lung_and_bronchus_male  ...  alc_exp_at_home  \
# year                                                     ...
# 1950         8.6            9.9                    24.3  ...       3455000000
# 1951         8.3           10.3                    25.8  ...       3789000000
# 1952         8.1           10.4                    28.0  ...       3999000000
# 1953         8.0           10.7                    30.4  ...       4080000000
# 1954         7.7           11.2                    31.7  ...       4189000000
#
#       alc_exp_away_fr_home  alc_exp_total  nox_per_capita  so_2_per_capita  \
# year
# 1950            4413000000     7868000000       87.872567       113.791573
# 1951            4765000000     8554000000       92.284438       117.679654
# 1952            4899000000     8898000000       92.125837       111.202933
# 1953            4960000000     9040000000       93.192457       111.909954
# 1954            4946000000     9135000000       90.616479       102.869296
#
#       co_per_capita  oc_per_capita  nmvoc_per_capita  bc_per_capita  \
# year
# 1950     660.499190       6.120093        106.463437       3.749932
# 1951     681.203964       5.698752        111.268008       3.501867
# 1952     680.903893       5.305718        112.090448       3.221975
# 1953     690.662295       4.836261        114.208577       2.935008
# 1954     674.088049       4.476236        112.303428       2.655331
#
#       nh_3_per_capita
# year
# 1950         9.289717
# 1951         9.570112
# 1952         9.744620
# 1953         9.946302
# 1954        10.007221
#
# [5 rows x 29 columns]

# %%
merged_df.columns
# Out:
# Index(['num_admissions_1000s', 'num_admissions_total', 'total_population',
#        'male_population', 'female_population', 'stomach_male',
#        'colon_and_rectum_male', 'liver_male', 'pancreas_male',
#        'lung_and_bronchus_male', 'prostate_male', 'leukemia_male',
#        'stomach_female', 'colon_and_rectum_female', 'pancreas_female',
#        'lung_and_bronchus_female', 'breast_female', 'uterus_female',
#        'liver_female', 'alc_exp_at_home', 'alc_exp_away_fr_home',
#        'alc_exp_total', 'nox_per_capita', 'so_2_per_capita', 'co_per_capita',
#        'oc_per_capita', 'nmvoc_per_capita', 'bc_per_capita',
#        'nh_3_per_capita'],
#       dtype='object')

# %%
df = merged_df.copy()

# %% [markdown]
# We have all the data joined and will perform the following processing:
# 1. Get the hospital admissions per capita
# 2. Get the complete death rate for each cancer type (remove separation by gender)
# 3. Get the complete death rate from all types of cancer
# 4. Get the alcohol expenditure values per capita

# %%
# get hospital admissions per capita
df['admissions_per_capita'] = df['num_admissions_total'] / df['total_population']

# %%
def cancer_deaths_helper(df, cancer_type):
    n_indiv = 100_000
    male_col = f"{cancer_type}_male"
    female_col = f"{cancer_type}_female"
    try:
        male_deaths = (df[male_col] / n_indiv) * df['male_population']
    except Exception as e:
        male_deaths = 0
    try:
        female_deaths = (df[female_col] / n_indiv) * df['female_population']
    except Exception as e:
        female_deaths = 0
    deaths = male_deaths + female_deaths
    total_rate = deaths / df['total_population']
    return total_rate

# %%
# get death rate per cancer type
cancer_types = ['stomach', 'colon_and_rectum', 'liver', 'pancreas', 'lung_and_bronchus',
                'prostate', 'leukemia', 'breast', 'uterus']

for cancer_type in cancer_types:
    df[cancer_type] = cancer_deaths_helper(df, cancer_type)

# %%
# get cancer death rates total
df['all_cancer'] = 0
for cancer_type in cancer_types:
    df['all_cancer'] += df[cancer_type]

# %%
# get alcohol expenditure per capita
df['alc_exp_at_home_per_capita'] = df['alc_exp_at_home'] / df['total_population']
df['alc_exp_away_fr_home_per_capita'] = df['alc_exp_away_fr_home'] / df['total_population']
df['alc_exp_total_per_capita'] = df['alc_exp_total'] / df['total_population']

# %%
df.columns
# Out:
# Index(['num_admissions_1000s', 'num_admissions_total', 'total_population',
#        'male_population', 'female_population', 'stomach_male',
#        'colon_and_rectum_male', 'liver_male', 'pancreas_male',
#        'lung_and_bronchus_male', 'prostate_male', 'leukemia_male',
#        'stomach_female', 'colon_and_rectum_female', 'pancreas_female',
#        'lung_and_bronchus_female', 'breast_female', 'uterus_female',
#        'liver_female', 'alc_exp_at_home', 'alc_exp_away_fr_home',
#        'alc_exp_total', 'nox_per_capita', 'so_2_per_capita', 'co_per_capita',
#        'oc_per_capita', 'nmvoc_per_capita', 'bc_per_capita', 'nh_3_per_capita',
#        'admissions_per_capita', 'stomach', 'colon_and_rectum', 'liver',
#        'pancreas', 'lung_and_bronchus', 'prostate', 'leukemia', 'breast',
#        'uterus', 'all_cancer', 'alc_exp_at_home_per_capita',
#        'alc_exp_away_fr_home_per_capita', 'alc_exp_total_per_capita'],
#       dtype='object')

# %%
columns_of_interest = [
    'stomach_male', 'colon_and_rectum_male', 'liver_male', 'pancreas_male',
    'lung_and_bronchus_male', 'prostate_male', 'leukemia_male',
    'stomach_female', 'colon_and_rectum_female', 'pancreas_female',
    'lung_and_bronchus_female', 'breast_female', 'uterus_female',
    'liver_female', 'nox_per_capita', 'so_2_per_capita', 'co_per_capita',
    'oc_per_capita', 'nmvoc_per_capita', 'bc_per_capita', 'nh_3_per_capita',
    'admissions_per_capita', 'stomach', 'colon_and_rectum', 'liver',
    'pancreas', 'lung_and_bronchus', 'prostate', 'leukemia', 'breast', 'uterus',
    'all_cancer', 'alc_exp_at_home_per_capita',
    'alc_exp_away_fr_home_per_capita', 'alc_exp_total_per_capita'
]
df_clean = df[columns_of_interest]

# %%
df_clean
# Out:
#       stomach_male  colon_and_rectum_male  liver_male  pancreas_male  \
# year
# 1950          31.1                   33.1         8.6            9.9
# 1951          29.7                   32.3         8.3           10.3
# 1952          28.7                   32.8         8.1           10.4
# 1953          28.1                   33.0         8.0           10.7
# 1954          27.3                   32.6         7.7           11.2
# ...            ...                    ...         ...            ...
# 2007           5.0                   20.7         8.9           12.6
# 2008           4.9                   20.1         9.3           12.5
# 2009           4.7                   19.5         9.6           12.4
# 2010           4.6                   19.2         9.7           12.7
# 2011           4.4                   18.5        10.0           12.5
#
#       lung_and_bronchus_male  prostate_male  leukemia_male  stomach_female  \
# year
# 1950                    24.3           28.9            8.2            17.6
# 1951                    25.8           28.6            8.7            16.5
# 1952                    28.0           29.7            8.8            16.1
# 1953                    30.4           29.8            9.1            15.6
# 1954                    31.7           30.5            9.4            14.8
# ...                      ...            ...            ...             ...
# 2007                    65.4           24.2            9.5             2.6
# 2008                    63.9           23.0            9.5             2.5
# 2009                    61.7           22.1            9.5             2.4
# 2010                    60.3           21.8            9.3             2.5
# 2011                    58.1           20.8            9.3             2.3
#
#       colon_and_rectum_female  pancreas_female  ...  pancreas  \
# year                                            ...
# 1950                     32.3              6.8  ...  0.000083
# 1951                     31.9              6.7  ...  0.000085
# 1952                     31.5              7.1  ...  0.000087
# 1953                     31.4              7.1  ...  0.000089
# 1954                     31.2              7.3  ...  0.000092
# ...                       ...              ...  ...       ...
# 2007                     14.6              9.5  ...   0.00011
# 2008                     14.3              9.7  ...  0.000111
# 2009                     13.6              9.5  ...  0.000109
# 2010                     13.3              9.6  ...  0.000111
# 2011                     13.1              9.5  ...   0.00011
#
#       lung_and_bronchus  prostate  leukemia    breast    uterus  all_cancer  \
# year
# 1950            0.00015  0.000143  0.000041  0.000161  0.000132    0.001372
# 1951           0.000158  0.000142  0.000043  0.000159  0.000123     0.00135
# 1952            0.00017  0.000148  0.000044  0.000159   0.00012     0.00136
# 1953           0.000181  0.000148  0.000045  0.000162  0.000119     0.00137
# 1954           0.000188  0.000151  0.000047   0.00016  0.000113    0.001363
# ...                 ...       ...       ...       ...       ...         ...
# 2007           0.000526  0.000119  0.000047  0.000117  0.000033    0.001233
# 2008           0.000514  0.000113  0.000047  0.000115  0.000033    0.001209
# 2009             0.0005  0.000109  0.000047  0.000113  0.000033    0.001181
# 2010            0.00049  0.000107  0.000046  0.000111  0.000034    0.001168
# 2011           0.000474  0.000102  0.000046  0.000109  0.000034     0.00114
#
#       alc_exp_at_home_per_capita  alc_exp_away_fr_home_per_capita  \
# year
# 1950                23300.268982                     29760.951379
# 1951                25159.620996                      31640.43126
# 1952                26147.213572                     32031.807775
# 1953                26246.179034                      31907.11961
# 1954                26478.157356                     31263.061897
# ...                          ...                              ...
# 2007               230368.876571                    224586.234496
# 2008               258529.931192                    228607.012135
# 2009                253807.03168                    222535.889078
# 2010               261257.636812                    225131.305037
# 2011               270901.481072                    233082.039678
#
#       alc_exp_total_per_capita
# year
# 1950              53061.220361
# 1951              56800.052256
# 1952              58179.021347
# 1953              58153.298644
# 1954              57741.219253
# ...                        ...
# 2007             454955.111068
# 2008             487136.943327
# 2009             476342.920758
# 2010             486388.941849
# 2011              503983.52075
#
# [62 rows x 35 columns]

# %%
df_clean.head()
# Out:
#       stomach_male  colon_and_rectum_male  liver_male  pancreas_male  \
# year
# 1950          31.1                   33.1         8.6            9.9
# 1951          29.7                   32.3         8.3           10.3
# 1952          28.7                   32.8         8.1           10.4
# 1953          28.1                   33.0         8.0           10.7
# 1954          27.3                   32.6         7.7           11.2
#
#       lung_and_bronchus_male  prostate_male  leukemia_male  stomach_female  \
# year
# 1950                    24.3           28.9            8.2            17.6
# 1951                    25.8           28.6            8.7            16.5
# 1952                    28.0           29.7            8.8            16.1
# 1953                    30.4           29.8            9.1            15.6
# 1954                    31.7           30.5            9.4            14.8
#
#       colon_and_rectum_female  pancreas_female  ...  pancreas  \
# year                                            ...
# 1950                     32.3              6.8  ...  0.000083
# 1951                     31.9              6.7  ...  0.000085
# 1952                     31.5              7.1  ...  0.000087
# 1953                     31.4              7.1  ...  0.000089
# 1954                     31.2              7.3  ...  0.000092
#
#       lung_and_bronchus  prostate  leukemia    breast    uterus  all_cancer  \
# year
# 1950            0.00015  0.000143  0.000041  0.000161  0.000132    0.001372
# 1951           0.000158  0.000142  0.000043  0.000159  0.000123     0.00135
# 1952            0.00017  0.000148  0.000044  0.000159   0.00012     0.00136
# 1953           0.000181  0.000148  0.000045  0.000162  0.000119     0.00137
# 1954           0.000188  0.000151  0.000047   0.00016  0.000113    0.001363
#
#       alc_exp_at_home_per_capita  alc_exp_away_fr_home_per_capita  \
# year
# 1950                23300.268982                     29760.951379
# 1951                25159.620996                      31640.43126
# 1952                26147.213572                     32031.807775
# 1953                26246.179034                      31907.11961
# 1954                26478.157356                     31263.061897
#
#       alc_exp_total_per_capita
# year
# 1950              53061.220361
# 1951              56800.052256
# 1952              58179.021347
# 1953              58153.298644
# 1954              57741.219253
#
# [5 rows x 35 columns]

# %% [markdown]
# `N.B. I'm leavin the male and female cancer stuff there in case we want to do some EDA split by gender`

# %%
columns_of_interest_2 = [
    'stomach_male', 'colon_and_rectum_male', 'liver_male', 'pancreas_male',
    'lung_and_bronchus_male', 'prostate_male', 'leukemia_male',
    'stomach_female', 'colon_and_rectum_female', 'pancreas_female',
    'lung_and_bronchus_female', 'breast_female', 'uterus_female',
    'liver_female', 'nox_per_capita', 'so_2_per_capita', 'co_per_capita',
    'oc_per_capita', 'nmvoc_per_capita', 'bc_per_capita', 'nh_3_per_capita',
    'admissions_per_capita', 'alc_exp_at_home_per_capita',
    'alc_exp_away_fr_home_per_capita', 'alc_exp_total_per_capita'
]
df_clean_2 = df_clean[columns_of_interest_2]

# %%
# corplot of df_clean2
df_clean_2.corr()
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\1546494987.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_clean_2.corr()
#                           stomach_male  colon_and_rectum_male  liver_male  \
# stomach_male                  1.000000               0.617239   -0.152724
# colon_and_rectum_male         0.617239               1.000000   -0.854703
# liver_male                   -0.152724              -0.854703    1.000000
# pancreas_male                -0.340628               0.238355   -0.575354
# lung_and_bronchus_male       -0.826766              -0.099773   -0.359203
# prostate_male                -0.052305               0.520731   -0.613303
# leukemia_male                -0.268410               0.466495   -0.777989
# stomach_female                0.996975               0.563502   -0.085036
# colon_and_rectum_female       0.916017               0.869307   -0.525329
# pancreas_female              -0.976867              -0.610163    0.157909
# lung_and_bronchus_female     -0.907203              -0.717924    0.369061
# breast_female                 0.539484               0.960992   -0.832501
# uterus_female                 0.993924               0.557232   -0.087081
# liver_female                  0.958741               0.376719    0.126225
# nox_per_capita                0.418585               0.923061   -0.893017
# so_2_per_capita               0.678190               0.925560   -0.747184
# co_per_capita                 0.661659               0.946336   -0.784924
# oc_per_capita                 0.877438               0.738290   -0.340602
# nmvoc_per_capita              0.636984               0.921229   -0.773108
# bc_per_capita                 0.943223               0.704383   -0.270676
# nh_3_per_capita              -0.644883               0.016091   -0.438066
#
#                           pancreas_male  lung_and_bronchus_male  \
# stomach_male                  -0.340628               -0.826766
# colon_and_rectum_male          0.238355               -0.099773
# liver_male                    -0.575354               -0.359203
# pancreas_male                  1.000000                0.444605
# lung_and_bronchus_male         0.444605                1.000000
# prostate_male                  0.055214                0.535641
# leukemia_male                  0.847717                0.570381
# stomach_female                -0.392766               -0.856160
# colon_and_rectum_female       -0.022109               -0.575939
# pancreas_female                0.350063                0.802161
# lung_and_bronchus_female      -0.062056                0.717907
# breast_female                  0.176913                0.011240
# uterus_female                 -0.330425               -0.874478
# liver_female                  -0.492693               -0.934844
# nox_per_capita                 0.470216                0.070632
# so_2_per_capita                0.327093               -0.265076
# co_per_capita                  0.350422               -0.236209
# oc_per_capita                 -0.364358               -0.543852
# nmvoc_per_capita               0.405659               -0.236307
# bc_per_capita                 -0.322889               -0.673965
# nh_3_per_capita                0.797667                0.741921
#
#                           prostate_male  leukemia_male  stomach_female  \
# stomach_male                  -0.052305      -0.268410        0.996975
# colon_and_rectum_male          0.520731       0.466495        0.563502
# liver_male                    -0.613303      -0.777989       -0.085036
# pancreas_male                  0.055214       0.847717       -0.392766
# lung_and_bronchus_male         0.535641       0.570381       -0.856160
# prostate_male                  1.000000       0.483313       -0.095096
# leukemia_male                  0.483313       1.000000       -0.331583
# stomach_female                -0.095096      -0.331583        1.000000
# colon_and_rectum_female        0.166059       0.105542        0.886242
# pancreas_female                0.078701       0.283570       -0.975141
# lung_and_bronchus_female       0.133303      -0.036091       -0.885206
# breast_female                  0.688096       0.469225        0.484065
# uterus_female                 -0.142163      -0.295918        0.995021
# liver_female                  -0.235433      -0.478347        0.975149
# nox_per_capita                 0.475955       0.612985        0.358975
# so_2_per_capita                0.280899       0.413129        0.629237
# co_per_capita                  0.280280       0.440969        0.610303
# oc_per_capita                  0.196228      -0.214327        0.866774
# nmvoc_per_capita               0.235679       0.467428        0.585102
# bc_per_capita                  0.057602      -0.243667        0.936312
# nh_3_per_capita                0.160711       0.701167       -0.681615
#
#                           colon_and_rectum_female  pancreas_female  ...  \
# stomach_male                             0.916017        -0.976867  ...
# colon_and_rectum_male                    0.869307        -0.610163  ...
# liver_male                              -0.525329         0.157909  ...
# pancreas_male                           -0.022109         0.350063  ...
# lung_and_bronchus_male                  -0.575939         0.802161  ...
# prostate_male                            0.166059         0.078701  ...
# leukemia_male                            0.105542         0.283570  ...
# stomach_female                           0.886242        -0.975141  ...
# colon_and_rectum_female                  1.000000        -0.900502  ...
# pancreas_female                         -0.900502         1.000000  ...
# lung_and_bronchus_female                -0.944321         0.891732  ...
# breast_female                            0.784189        -0.518148  ...
# uterus_female                            0.890197        -0.970484  ...
# liver_female                             0.771312        -0.935386  ...
# nox_per_capita                           0.729188        -0.447228  ...
# so_2_per_capita                          0.895840        -0.689343  ...
# co_per_capita                            0.896425        -0.668996  ...
# oc_per_capita                            0.870099        -0.868356  ...
# nmvoc_per_capita                         0.875683        -0.643996  ...
# bc_per_capita                            0.911370        -0.950931  ...
# nh_3_per_capita                         -0.347607         0.585399  ...
#
#                           breast_female  uterus_female  liver_female  \
# stomach_male                   0.539484       0.993924      0.958741
# colon_and_rectum_male          0.960992       0.557232      0.376719
# liver_male                    -0.832501      -0.087081      0.126225
# pancreas_male                  0.176913      -0.330425     -0.492693
# lung_and_bronchus_male         0.011240      -0.874478     -0.934844
# prostate_male                  0.688096      -0.142163     -0.235433
# leukemia_male                  0.469225      -0.295918     -0.478347
# stomach_female                 0.484065       0.995021      0.975149
# colon_and_rectum_female        0.784189       0.890197      0.771312
# pancreas_female               -0.518148      -0.970484     -0.935386
# lung_and_bronchus_female      -0.585545      -0.913415     -0.810975
# breast_female                  1.000000       0.468028      0.299970
# uterus_female                  0.468028       1.000000      0.973110
# liver_female                   0.299970       0.973110      1.000000
# nox_per_capita                 0.876152       0.366795      0.170742
# so_2_per_capita                0.849489       0.646081      0.472038
# co_per_capita                  0.861885       0.626370      0.445294
# oc_per_capita                  0.696354       0.834073      0.773777
# nmvoc_per_capita               0.827796       0.607924      0.425845
# bc_per_capita                  0.632311       0.918296      0.864440
# nh_3_per_capita               -0.008956      -0.653897     -0.762214
#
#                           nox_per_capita  so_2_per_capita  co_per_capita  \
# stomach_male                    0.418585         0.678190       0.661659
# colon_and_rectum_male           0.923061         0.925560       0.946336
# liver_male                     -0.893017        -0.747184      -0.784924
# pancreas_male                   0.470216         0.327093       0.350422
# lung_and_bronchus_male          0.070632        -0.265076      -0.236209
# prostate_male                   0.475955         0.280899       0.280280
# leukemia_male                   0.612985         0.413129       0.440969
# stomach_female                  0.358975         0.629237       0.610303
# colon_and_rectum_female         0.729188         0.895840       0.896425
# pancreas_female                -0.447228        -0.689343      -0.668996
# lung_and_bronchus_female       -0.613972        -0.837175      -0.836190
# breast_female                   0.876152         0.849489       0.861885
# uterus_female                   0.366795         0.646081       0.626370
# liver_female                    0.170742         0.472038       0.445294
# nox_per_capita                  1.000000         0.937507       0.940725
# so_2_per_capita                 0.937507         1.000000       0.987841
# co_per_capita                   0.940725         0.987841       1.000000
# oc_per_capita                   0.523108         0.681519       0.692511
# nmvoc_per_capita                0.934730         0.982796       0.995388
# bc_per_capita                   0.550939         0.749535       0.732817
# nh_3_per_capita                 0.331535         0.067983       0.077830
#
#                           oc_per_capita  nmvoc_per_capita  bc_per_capita  \
# stomach_male                   0.877438          0.636984       0.943223
# colon_and_rectum_male          0.738290          0.921229       0.704383
# liver_male                    -0.340602         -0.773108      -0.270676
# pancreas_male                 -0.364358          0.405659      -0.322889
# lung_and_bronchus_male        -0.543852         -0.236307      -0.673965
# prostate_male                  0.196228          0.235679       0.057602
# leukemia_male                 -0.214327          0.467428      -0.243667
# stomach_female                 0.866774          0.585102       0.936312
# colon_and_rectum_female        0.870099          0.875683       0.911370
# pancreas_female               -0.868356         -0.643996      -0.950931
# lung_and_bronchus_female      -0.762255         -0.838497      -0.857494
# breast_female                  0.696354          0.827796       0.632311
# uterus_female                  0.834073          0.607924       0.918296
# liver_female                   0.773777          0.425845       0.864440
# nox_per_capita                 0.523108          0.934730       0.550939
# so_2_per_capita                0.681519          0.982796       0.749535
# co_per_capita                  0.692511          0.995388       0.732817
# oc_per_capita                  1.000000          0.648417       0.952877
# nmvoc_per_capita               0.648417          1.000000       0.701364
# bc_per_capita                  0.952877          0.701364       1.000000
# nh_3_per_capita               -0.532183          0.122275      -0.503019
#
#                           nh_3_per_capita
# stomach_male                    -0.644883
# colon_and_rectum_male            0.016091
# liver_male                      -0.438066
# pancreas_male                    0.797667
# lung_and_bronchus_male           0.741921
# prostate_male                    0.160711
# leukemia_male                    0.701167
# stomach_female                  -0.681615
# colon_and_rectum_female         -0.347607
# pancreas_female                  0.585399
# lung_and_bronchus_female         0.334552
# breast_female                   -0.008956
# uterus_female                   -0.653897
# liver_female                    -0.762214
# nox_per_capita                   0.331535
# so_2_per_capita                  0.067983
# co_per_capita                    0.077830
# oc_per_capita                   -0.532183
# nmvoc_per_capita                 0.122275
# bc_per_capita                   -0.503019
# nh_3_per_capita                  1.000000
#
# [21 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

# %%
columns_of_interest_3 = [
    'stomach_male', 'colon_and_rectum_male', 'liver_male', 'pancreas_male',
    'lung_and_bronchus_male', 'prostate_male', 'leukemia_male',
     'nox_per_capita', 'so_2_per_capita', 'co_per_capita',
    'oc_per_capita', 'nmvoc_per_capita', 'bc_per_capita', 'nh_3_per_capita',
    'admissions_per_capita', 'alc_exp_at_home_per_capita',
    'alc_exp_away_fr_home_per_capita', 'alc_exp_total_per_capita'
]
df_clean_3 = df_clean[columns_of_interest_3]
fig, ax = plt.subplots(figsize=(15, 15))
matrix = df_clean_3.corr().round(2)
sns.heatmap(matrix, annot=False, ax= ax)
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\213499523.py:11: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df_clean_3.corr().round(2)
# <AxesSubplot: >

# %%
# Create List of columns
col_list= ['stomach_male', 'colon_and_rectum_male', 'liver_male', 'pancreas_male',
    'lung_and_bronchus_male', 'prostate_male', 'leukemia_male']

df_clean['Male_Cancer_Sum'] = df_clean[col_list].sum(axis=1)
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\335224525.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Male_Cancer_Sum'] = df_clean[col_list].sum(axis=1)

# %%
col_list_female = ['stomach_female', 'colon_and_rectum_female', 'pancreas_female',
    'lung_and_bronchus_female', 'breast_female', 'uterus_female',
    'liver_female']

df_clean['Female_Cancer_sum'] = df_clean[col_list_female].sum(axis=1)
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\346312876.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Female_Cancer_sum'] = df_clean[col_list_female].sum(axis=1)

# %%
col_list = ['Male_Cancer_Sum','Female_Cancer_sum','nox_per_capita', 'so_2_per_capita', 'co_per_capita',
    'oc_per_capita', 'nmvoc_per_capita', 'bc_per_capita', 'nh_3_per_capita',
    'admissions_per_capita', 'stomach', 'colon_and_rectum', 'liver',
    'pancreas', 'lung_and_bronchus', 'prostate', 'leukemia', 'breast', 'uterus',
    'all_cancer', 'alc_exp_at_home_per_capita',
    'alc_exp_away_fr_home_per_capita', 'alc_exp_total_per_capita']

df_clean4 = df_clean[col_list]

df_clean4['cancer_total'] =  df_clean4['Male_Cancer_Sum']+ df_clean4['Female_Cancer_sum']

fig, ax = plt.subplots(figsize=(10, 7))
matrix = df_clean4.corr().round(2)
sns.heatmap(matrix, annot=True, ax= ax)
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\3598473754.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean4['cancer_total'] =  df_clean4['Male_Cancer_Sum']+ df_clean4['Female_Cancer_sum']
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\3598473754.py:13: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df_clean4.corr().round(2)
# <AxesSubplot: >

# %% [markdown]
# - The correlation coefficient between male cancer (0.59) and female cancer (-0.66) with NH3 per capita. In this instance, a moderately positive link between male cancer rates and NH3 emissions per capita is indicated by the positive correlation coefficient for male cancer and NH3 per capita of 0.59. This suggests that as NH3 emissions per person rise, male cancer rates tend to rise as well. It's crucial to remember that correlation does not imply causation and that other factors can be at play in the link that has been noticed. It's critical to undertake additional research and take other potential influences on cancer rates into account, such as age, genetics, lifestyle, and other environmental factor as correlation doesn't mean association.
#
# - If the correlation between OC and BC emissions or concentrations with respect to per capita measurements is higher in females than in males, this indicates that there is a stronger association between OC and BC emissions or concentrations in females as compared to males. A larger correlation indicates that females, as opposed to males, are more frequently connected with changes in OC per capita and changes in BC per capita. There could be a number of explanations for this difference in correlation between males and females, including variations in exposure patterns, behaviors, or physiological traits between the sexes. The correlation between OC and BC emissions and their health effects may be altered by biological fluctuations, such as hormonal changes. To fully understand the underlying causes of the observed difference in correlation between males and females regarding OC and BC per capita, more research would be required. Given the limitations of correlation analysis and the need for further research to establish any causal connections or fully comprehend the patterns, it is crucial to take into account additional variables and factors that may be influencing the relationship and to interpret the results with caution.

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(15, 15))
matrix = df_clean_2.corr().round(2)
sns.heatmap(matrix, annot=False, ax= ax)
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\1102366701.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df_clean_2.corr().round(2)
# <AxesSubplot: >

# %%
sns.heatmap(df_clean_2.corr())
# Out:
# C:\Users\gvnsp\AppData\Local\Temp\ipykernel_11276\149748082.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_clean_2.corr())
# <AxesSubplot: >

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.graphics.mosaicplot import mosaic

# %%
df_clean4.columns
# Out:
# Index(['Male_Cancer_Sum', 'Female_Cancer_sum', 'nox_per_capita',
#        'so_2_per_capita', 'co_per_capita', 'oc_per_capita', 'nmvoc_per_capita',
#        'bc_per_capita', 'nh_3_per_capita', 'admissions_per_capita', 'stomach',
#        'colon_and_rectum', 'liver', 'pancreas', 'lung_and_bronchus',
#        'prostate', 'leukemia', 'breast', 'uterus', 'all_cancer',
#        'alc_exp_at_home_per_capita', 'alc_exp_away_fr_home_per_capita',
#        'alc_exp_total_per_capita', 'cancer_total'],
#       dtype='object')

# %%
y = df_clean4['cancer_total']
X = df_clean4.drop(['cancer_total'], axis=1)

# %%
#!pip install mlxtend
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()

sfs1 = sfs(lreg, k_features=4, forward=False, verbose=1, scoring='neg_mean_squared_error')
sfs1 = sfs1.fit(X, y)
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.4 MB 1.2 MB/s eta 0:00:02
#      ------ --------------------------------- 0.2/1.4 MB 2.0 MB/s eta 0:00:01
#      -------- ------------------------------- 0.3/1.4 MB 1.7 MB/s eta 0:00:01
#      --------- ------------------------------ 0.3/1.4 MB 1.6 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.4/1.4 MB 1.5 MB/s eta 0:00:01
#      ------------ --------------------------- 0.4/1.4 MB 1.5 MB/s eta 0:00:01
#      -------------- ------------------------- 0.5/1.4 MB 1.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.6/1.4 MB 1.5 MB/s eta 0:00:01
#      ------------------- -------------------- 0.6/1.4 MB 1.5 MB/s eta 0:00:01
#      --------------------- ------------------ 0.7/1.4 MB 1.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 0.8/1.4 MB 1.5 MB/s eta 0:00:01
#      -------------------------- ------------- 0.9/1.4 MB 1.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 1.0/1.4 MB 1.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.0/1.4 MB 1.5 MB/s eta 0:00:01
#      -------------------------------- ------- 1.1/1.4 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 1.2/1.4 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 1.3/1.4 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  1.4/1.4 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (1.2.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: setuptools in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (58.1.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (1.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\gvnsp\si618\.venv\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gvnsp\si618\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gvnsp\si618\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gvnsp\si618\.venv\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\gvnsp\si618\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.2s finished
# Features: 22/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.1s finished
# Features: 21/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.1s finished
# Features: 20/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.1s finished
# Features: 19/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.1s finished
# Features: 18/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.1s finished
# Features: 17/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.1s finished
# Features: 16/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.1s finished
# Features: 15/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.1s finished
# Features: 14/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.1s finished
# Features: 13/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.0s finished
# Features: 12/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.0s finished
# Features: 11/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.0s finished
# Features: 10/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
# Features: 9/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s finished
# Features: 8/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Features: 7/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s finished
# Features: 6/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s finished
# Features: 5/4[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# Features: 4/4

# %%
feat_names = list(sfs1.k_feature_names_)
print(feat_names)
# Out:
# ['Male_Cancer_Sum', 'Female_Cancer_sum', 'admissions_per_capita', 'stomach']

# %% [markdown]
# # EDA

# %% [markdown]
# # Analysis/Modelling
